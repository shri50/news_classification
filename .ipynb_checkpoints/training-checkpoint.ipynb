# %%
import pandas as pd
import numpy as np
import ydata_profiling

# %%
DATASET_PATH = r"dataset/News_Category_Dataset_v3.json"

# %%
df = pd.read_json(DATASET_PATH, lines=True)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209527 entries, 0 to 209526
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   link               209527 non-null  object
#  1   headline           209527 non-null  object
#  2   category           209527 non-null  object
#  3   short_description  209527 non-null  object
#  4   authors            209527 non-null  object
#  5   date               209527 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.6+ MB

# %%
df.describe(include='all')
# Out:
#                                                      link        headline  \
# count                                              209527          209527
# unique                                             209486          207996
# top     https://www.huffingtonpost.comhttps://www.wash...  Sunday Roundup
# freq                                                    2              90
# mean                                                  NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#         category short_description authors                           date
# count     209527            209527  209527                         209527
# unique        42            187022   29169                            NaN
# top     POLITICS                                                      NaN
# freq       35602             19712   37418                            NaN
# mean         NaN               NaN     NaN  2015-04-30 00:44:14.344308736
# min          NaN               NaN     NaN            2012-01-28 00:00:00
# 25%          NaN               NaN     NaN            2013-08-10 00:00:00
# 50%          NaN               NaN     NaN            2015-03-16 00:00:00
# 75%          NaN               NaN     NaN            2016-11-01 00:00:00
# max          NaN               NaN     NaN            2022-09-23 00:00:00

# %%
df.describe(include='all').style.set_properties(**{"background-color":"#00539C",
                                                "color":"#EEA47F"})
# Out:
# <style type="text/css">
# #T_4769d_row0_col0, #T_4769d_row0_col1, #T_4769d_row0_col2, #T_4769d_row0_col3, #T_4769d_row0_col4, #T_4769d_row0_col5, #T_4769d_row1_col0, #T_4769d_row1_col1, #T_4769d_row1_col2, #T_4769d_row1_col3, #T_4769d_row1_col4, #T_4769d_row1_col5, #T_4769d_row2_col0, #T_4769d_row2_col1, #T_4769d_row2_col2, #T_4769d_row2_col3, #T_4769d_row2_col4, #T_4769d_row2_col5, #T_4769d_row3_col0, #T_4769d_row3_col1, #T_4769d_row3_col2, #T_4769d_row3_col3, #T_4769d_row3_col4, #T_4769d_row3_col5, #T_4769d_row4_col0, #T_4769d_row4_col1, #T_4769d_row4_col2, #T_4769d_row4_col3, #T_4769d_row4_col4, #T_4769d_row4_col5, #T_4769d_row5_col0, #T_4769d_row5_col1, #T_4769d_row5_col2, #T_4769d_row5_col3, #T_4769d_row5_col4, #T_4769d_row5_col5, #T_4769d_row6_col0, #T_4769d_row6_col1, #T_4769d_row6_col2, #T_4769d_row6_col3, #T_4769d_row6_col4, #T_4769d_row6_col5, #T_4769d_row7_col0, #T_4769d_row7_col1, #T_4769d_row7_col2, #T_4769d_row7_col3, #T_4769d_row7_col4, #T_4769d_row7_col5, #T_4769d_row8_col0, #T_4769d_row8_col1, #T_4769d_row8_col2, #T_4769d_row8_col3, #T_4769d_row8_col4, #T_4769d_row8_col5, #T_4769d_row9_col0, #T_4769d_row9_col1, #T_4769d_row9_col2, #T_4769d_row9_col3, #T_4769d_row9_col4, #T_4769d_row9_col5 {
#   background-color: #00539C;
#   color: #EEA47F;
# }
# </style>
# <table id="T_4769d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4769d_level0_col0" class="col_heading level0 col0" >link</th>
#       <th id="T_4769d_level0_col1" class="col_heading level0 col1" >headline</th>
#       <th id="T_4769d_level0_col2" class="col_heading level0 col2" >category</th>
#       <th id="T_4769d_level0_col3" class="col_heading level0 col3" >short_description</th>
#       <th id="T_4769d_level0_col4" class="col_heading level0 col4" >authors</th>
#       <th id="T_4769d_level0_col5" class="col_heading level0 col5" >date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4769d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4769d_row0_col0" class="data row0 col0" >209527</td>
#       <td id="T_4769d_row0_col1" class="data row0 col1" >209527</td>
#       <td id="T_4769d_row0_col2" class="data row0 col2" >209527</td>
#       <td id="T_4769d_row0_col3" class="data row0 col3" >209527</td>
#       <td id="T_4769d_row0_col4" class="data row0 col4" >209527</td>
#       <td id="T_4769d_row0_col5" class="data row0 col5" >209527</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_4769d_row1_col0" class="data row1 col0" >209486</td>
#       <td id="T_4769d_row1_col1" class="data row1 col1" >207996</td>
#       <td id="T_4769d_row1_col2" class="data row1 col2" >42</td>
#       <td id="T_4769d_row1_col3" class="data row1 col3" >187022</td>
#       <td id="T_4769d_row1_col4" class="data row1 col4" >29169</td>
#       <td id="T_4769d_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_4769d_row2_col0" class="data row2 col0" >https://www.huffingtonpost.comhttps://www.washingtonpost.com/politics/divisions-within-gop-over-trumps-candidacy-are-growing/2016/02/28/97b16010-de3a-11e5-8d98-4b3d9215ade1_story.html</td>
#       <td id="T_4769d_row2_col1" class="data row2 col1" >Sunday Roundup</td>
#       <td id="T_4769d_row2_col2" class="data row2 col2" >POLITICS</td>
#       <td id="T_4769d_row2_col3" class="data row2 col3" ></td>
#       <td id="T_4769d_row2_col4" class="data row2 col4" ></td>
#       <td id="T_4769d_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_4769d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_4769d_row3_col1" class="data row3 col1" >90</td>
#       <td id="T_4769d_row3_col2" class="data row3 col2" >35602</td>
#       <td id="T_4769d_row3_col3" class="data row3 col3" >19712</td>
#       <td id="T_4769d_row3_col4" class="data row3 col4" >37418</td>
#       <td id="T_4769d_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row4" class="row_heading level0 row4" >mean</th>
#       <td id="T_4769d_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_4769d_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_4769d_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_4769d_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_4769d_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_4769d_row4_col5" class="data row4 col5" >2015-04-30 00:44:14.344308736</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row5" class="row_heading level0 row5" >min</th>
#       <td id="T_4769d_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_4769d_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_4769d_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_4769d_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_4769d_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_4769d_row5_col5" class="data row5 col5" >2012-01-28 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row6" class="row_heading level0 row6" >25%</th>
#       <td id="T_4769d_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_4769d_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_4769d_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_4769d_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_4769d_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_4769d_row6_col5" class="data row6 col5" >2013-08-10 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row7" class="row_heading level0 row7" >50%</th>
#       <td id="T_4769d_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_4769d_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_4769d_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_4769d_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_4769d_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_4769d_row7_col5" class="data row7 col5" >2015-03-16 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row8" class="row_heading level0 row8" >75%</th>
#       <td id="T_4769d_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_4769d_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_4769d_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_4769d_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_4769d_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_4769d_row8_col5" class="data row8 col5" >2016-11-01 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_4769d_level0_row9" class="row_heading level0 row9" >max</th>
#       <td id="T_4769d_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_4769d_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_4769d_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_4769d_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_4769d_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_4769d_row9_col5" class="data row9 col5" >2022-09-23 00:00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.profile_report()
# Out:
# Summarize dataset:  60%|██████████████████████████████████▊                       | 9/15 [00:28<00:18,  3.15s/it, Missing diagram bar]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:518, in ProfileReport._repr_html_(self)
#     516 def _repr_html_(self) -> None:
#     517     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 518     self.to_notebook_iframe()
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:498, in ProfileReport.to_notebook_iframe(self)
#     496 with warnings.catch_warnings():
#     497     warnings.simplefilter("ignore")
# --> 498     display(get_notebook_iframe(self.config, self))
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:468, in ProfileReport.to_html(self)
#     460 def to_html(self) -> str:
#     461     """Generate and return complete template as lengthy string
#     462         for using with frameworks.
#     463
#    (...)
#     466
#     467     """
# --> 468     return self.html
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:275, in ProfileReport.html(self)
#     272 @property
#     273 def html(self) -> str:
#     274     if self._html is None:
# --> 275         self._html = self._render_html()
#     276     return self._html
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:383, in ProfileReport._render_html(self)
#     380 def _render_html(self) -> str:
#     381     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 383     report = self.report
#     385     with tqdm(
#     386         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     387     ) as pbar:
#     388         html = HTMLReport(copy.deepcopy(report)).render(
#     389             nav=self.config.html.navbar_show,
#     390             offline=self.config.html.use_local_assets,
#    (...)
#     398             version=self.description_set.package["ydata_profiling_version"],
#     399         )
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:269, in ProfileReport.report(self)
#     266 @property
#     267 def report(self) -> Root:
#     268     if self._report is None:
# --> 269         self._report = get_report_structure(self.config, self.description_set)
#     270     return self._report
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\profile_report.py:251, in ProfileReport.description_set(self)
#     248 @property
#     249 def description_set(self) -> BaseDescription:
#     250     if self._description_set is None:
# --> 251         self._description_set = describe_df(
#     252             self.config,
#     253             self.df,
#     254             self.summarizer,
#     255             self.typeset,
#     256             self._sample,
#     257         )
#     258     return self._description_set
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\model\describe.py:135, in describe(config, df, summarizer, typeset, sample)
#     133 missing_map = get_missing_active(config, table_stats)
#     134 pbar.total += len(missing_map)
# --> 135 missing = {
#     136     name: progress(get_missing_diagram, pbar, f"Missing diagram {name}")(
#     137         config, df, settings
#     138     )
#     139     for name, settings in missing_map.items()
#     140 }
#     141 missing = {name: value for name, value in missing.items() if value is not None}
#     143 # Sample
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\model\describe.py:136, in <dictcomp>(.0)
#     133 missing_map = get_missing_active(config, table_stats)
#     134 pbar.total += len(missing_map)
#     135 missing = {
# --> 136     name: progress(get_missing_diagram, pbar, f"Missing diagram {name}")(
#     137         config, df, settings
#     138     )
#     139     for name, settings in missing_map.items()
#     140 }
#     141 missing = {name: value for name, value in missing.items() if value is not None}
#     143 # Sample
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\model\missing.py:112, in get_missing_diagram(config, df, settings)
#     109 if len(df) == 0:
#     110     return None
# --> 112 result = handle_missing(settings["name"], settings["function"])(config, df)
#     113 if result is None:
#     114     return None
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\model\missing.py:88, in handle_missing.<locals>.inner(*args, **kwargs)
#      78             warnings.warn(
#      79                 f"""There was an attempt to generate the {missing_name} missing values diagrams, but this failed.
#      80 To hide this warning, disable the calculation
#    (...)
#      84 (include the error message: '{error}')"""
#      85             )
#      87         try:
# ---> 88             return fn(*args, *kwargs)
#      89         except ValueError as e:
#      90             warn_missing(name, str(e))
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\model\pandas\missing_pandas.py:16, in pandas_missing_bar(config, df)
#      13 @missing_bar.register
#      14 def pandas_missing_bar(config: Settings, df: pd.DataFrame) -> str:
#      15     notnull_counts = len(df) - df.isnull().sum()
# ---> 16     return plot_missing_bar(
#      17         config,
#      18         notnull_counts=notnull_counts,
#      19         nrows=len(df),
#      20         columns=list(df.columns),
#      21     )
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\visualisation\missing.py:84, in plot_missing_bar(config, notnull_counts, nrows, columns)
#      69 @manage_matplotlib_context()
#      70 def plot_missing_bar(
#      71     config: Settings, notnull_counts: list, nrows: int, columns: List[str]
#      72 ) -> str:
#      73     """Generate missing values bar plot.
#      74
#      75     Args:
#    (...)
#      82         The resulting missing values bar plot encoded as a string.
#      83     """
# ---> 84     missing_bar(
#      85         notnull_counts=notnull_counts,
#      86         nrows=nrows,
#      87         figsize=(10, 5),
#      88         fontsize=get_font_size(columns),
#      89         color=hex_to_rgb(config.html.style.primary_colors[0]),
#      90         labels=config.plot.missing.force_labels,
#      91     )
#      92     for ax0 in plt.gcf().get_axes():
#      93         ax0.grid(False)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\ydata_profiling\visualisation\plot.py:813, in missing_bar(notnull_counts, nrows, figsize, fontsize, labels, color, label_rotation)
#     810 percentage = notnull_counts / nrows
#     812 if len(notnull_counts) <= 50:
# --> 813     ax0 = percentage.plot.bar(figsize=figsize, fontsize=fontsize, color=color)
#     814     ax0.set_xticklabels(
#     815         ax0.get_xticklabels(),
#     816         ha="right",
#     817         fontsize=fontsize,
#     818         rotation=label_rotation,
#     819     )
#     821     ax1 = ax0.twiny()
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\plotting\_core.py:1136, in bar(self, x, y, **kwargs)
#    1063     """
#    1064     Plot Series or DataFrame as lines.
#    1065
#    1066     This function is useful to plot lines using DataFrame's values
#    1067     as coordinates.
#    1068     """
#    1069     return self(kind="line", x=x, y=y, **kwargs)
#    1071 @Appender(
#    1072     """
#    1073     See Also
#    1074     --------
#    1075     DataFrame.plot.barh : Horizontal bar plot.
#    1076     DataFrame.plot : Make plots of a DataFrame.
#    1077     matplotlib.pyplot.bar : Make a bar plot with matplotlib.
#    1078
#    1079     Examples
#    1080     --------
#    1081     Basic plot.
#    1082
#    1083     .. plot::
#    1084         :context: close-figs
#    1085
#    1086         >>> df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
#    1087         >>> ax = df.plot.bar(x='lab', y='val', rot=0)
#    1088
#    1089     Plot a whole dataframe to a bar plot. Each column is assigned a
#    1090     distinct color, and each row is nested in a group along the
#    1091     horizontal axis.
#    1092
#    1093     .. plot::
#    1094         :context: close-figs
#    1095
#    1096         >>> speed = [0.1, 17.5, 40, 48, 52, 69, 88]
#    1097         >>> lifespan = [2, 8, 70, 1.5, 25, 12, 28]
#    1098         >>> index = ['snail', 'pig', 'elephant',
#    1099         ...          'rabbit', 'giraffe', 'coyote', 'horse']
#    1100         >>> df = pd.DataFrame({'speed': speed,
#    1101         ...                    'lifespan': lifespan}, index=index)
#    1102         >>> ax = df.plot.bar(rot=0)
#    1103
#    1104     Plot stacked bar charts for the DataFrame
#    1105
#    1106     .. plot::
#    1107         :context: close-figs
#    1108
#    1109         >>> ax = df.plot.bar(stacked=True)
#    1110
#    1111     Instead of nesting, the figure can be split by column with
#    1112     ``subplots=True``. In this case, a :class:`numpy.ndarray` of
#    1113     :class:`matplotlib.axes.Axes` are returned.
#    1114
#    1115     .. plot::
#    1116         :context: close-figs
#    1117
#    1118         >>> axes = df.plot.bar(rot=0, subplots=True)
#    1119         >>> axes[1].legend(loc=2)  # doctest: +SKIP
#    1120
#    1121     If you don't like the default colours, you can specify how you'd
#    1122     like each column to be colored.
#    1123
#    1124     .. plot::
#    1125         :context: close-figs
#    1126
#    1127         >>> axes = df.plot.bar(
#    1128         ...     rot=0, subplots=True, color={"speed": "red", "lifespan": "green"}
#    1129         ... )
#    1130         >>> axes[1].legend(loc=2)  # doctest: +SKIP
#    1131
#    1132     Plot a single column.
#    1133
#    1134     .. plot::
#    1135         :context: close-figs
# -> 1136
#    1137         >>> ax = df.plot.bar(y='speed', rot=0)
#    1138
#    1139     Plot only selected categories for the DataFrame.
#    1140
#    1141     .. plot::
#    1142         :context: close-figs
#    1143
#    1144         >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1145 """
#    1146 )
#    1147 @Substitution(kind="bar")
#    1148 @Appender(_bar_or_line_doc)
#    1149 def bar(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1150     """
#    1151     Vertical bar plot.
#    1152
#    (...)
#    1157     other axis represents a measured value.
#    1158     """
#    1159     return self(kind="bar", x=x, y=y, **kwargs)
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\plotting\_core.py:975, in __call__(self, *args, **kwargs)
#     972 if int_y_arg and not data.columns.holds_integer():
#     973     y = data_cols[y]
# --> 975 label_kw = kwargs["label"] if "label" in kwargs else False
#     976 for kw in ["xerr", "yerr"]:
#     977     if kw in kwargs and (
#     978         isinstance(kwargs[kw], str) or is_integer(kwargs[kw])
#     979     ):
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# --> 450     self._compute_plot_data()
#     451     self._setup_subplots()
#     452     self._make_plot()
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\plotting\_matplotlib\core.py:608, in MPLPlot._compute_plot_data(self)
#     604     data = reconstruct_data_with_by(self.data, by=self.by, cols=self.columns)
#     606 # GH16953, _convert is needed as fallback, for ``Series``
#     607 # with ``dtype == object``
# --> 608 data = data._convert(datetime=True, timedelta=True)
#     609 include_type = [np.number, "datetime", "datetimetz", "timedelta"]
#     611 # GH23719, allow plotting boolean
#
# File C:\ProgramData\Miniconda3\envs\news_clf\lib\site-packages\pandas\core\generic.py:5989, in __getattr__(self, name)
#    5982 @final
#    5983 def _consolidate(self):
#    5984     """
#    5985     Compute NDFrame with "consolidated" internals (data of each dtype
#    5986     grouped together in a single ndarray).
#    5987
#    5988     Returns
# -> 5989     -------
#    5990     consolidated : same type as caller
#    5991     """
#    5992     f = lambda: self._mgr.consolidate()
#    5993     cons_data = self._protect_consolidate(f)
#
# AttributeError: 'DataFrame' object has no attribute '_convert'
